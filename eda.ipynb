# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import json

# %% [markdown]
# Step 1 Load data and check

# %%
file_path = 'emails.txt'

# %%
with open(file_path, 'r') as file:
    content = file.readlines()
df = pd.DataFrame(content, columns=['email'])
df['email'] = df['email'].str.replace('\n', '')
df
# Out:
#                                 email
# 0           Elody_OConner51@gmail.com
# 1               lily.long85@yahoo.com
# 2            simon.ward@protonmailcom
# 3       benjamin.phillips@hotmail.com
# 4               robert.walker@aol.com
# ...                               ...
# 1068         grace.hughes@hotmail.com
# 1069  grace92_anderson@protonmail.com
# 1070        Marshall_Upton32@mail.com
# 1071    caleb1996_phillips@icloud.com
# 1072     Floyd_Lueilwitz@tutanota.com
#
# [1073 rows x 1 columns]

# %% [markdown]
# Step 2 Fix typo/email format

# %%
def extract_email_domain(email):
    split_list = email.split('@')
    domain = ''.join(split_list[-1])
    #rest are username
    username = ''.join(split_list[:-1])
    return username, domain

# %%
# check format of emails
def check_email_format(domain):
    # only 1 . after @, and not the last character
    if domain.count('.') != 1:
        return False
    elif domain[-1] == '.':
        return False
    else:
        return True

# %%
df['username'], df['domain'] = zip(*df['email'].apply(extract_email_domain))
df['valid_email'] = df['domain'].apply(check_email_format)
df['valid_email'].value_counts()
# Out:
# valid_email
# True     999
# False     74
# Name: count, dtype: int64

# %%
df[df['valid_email'] == False]
# Out:
#                                email                   username  \
# 2           simon.ward@protonmailcom                 simon.ward
# 7               matthew.lewis@gmail,              matthew.lewis
# 16                peter.jackson@aol,              peter.jackson
# 17                 paul.baker@aolcom                 paul.baker
# 23          laura.foster@icloud..com               laura.foster
# ...                              ...                        ...
# 971         nancy.baker@outlook..com                nancy.baker
# 996              nancy.morris@yahoo,               nancy.morris
# 1022      laura.walker@protonmailcom               laura.walker
# 1037  matthew.roberts@protonmail@com  matthew.robertsprotonmail
# 1061         simon.peters@hotmailcom               simon.peters
#
#              domain  valid_email
# 2     protonmailcom        False
# 7            gmail,        False
# 16             aol,        False
# 17           aolcom        False
# 23      icloud..com        False
# ...             ...          ...
# 971    outlook..com        False
# 996          yahoo,        False
# 1022  protonmailcom        False
# 1037            com        False
# 1061     hotmailcom        False
#
# [74 rows x 4 columns]

# %% [markdown]
# typos:
# 1. missing ./ double . before com
# 2. , instead of .
# 3. missing com
# 3. additional @ in the user name, but we could assume it is correct
#
# Let's fix those, as we don't have too many data, so each data is valueable

# %%
df['valid_check'] = df['domain'].apply(check_email_format)
df['valid_check'].value_counts()
# Out:
# valid_check
# True     999
# False     74
# Name: count, dtype: int64

# %%
def insert_dot(domain):
    #if no dot, insert dot before com
    if '.' not in domain:
        domain = domain.replace('com', '.com')
    return domain

# %%
# replace all , with .
df['domain'] = df['domain'].str.replace(',', '.')
# insert . before com if missing
df['domain'] = df['domain'].apply(insert_dot)
# add com if missing
df['domain'] = df['domain'].apply(lambda x: x if x[-1] != '.' else x+'com')
# replace .. with .
df['domain'] = df['domain'].str.replace('..', '.')
df['valid_check'] = df['domain'].apply(check_email_format)

# %%
df[df['valid_check'] == False]
# Out:
#                                   email            username            domain  \
# 88                   sarah.carter@yahoo        sarah.carter             yahoo
# 150     emily_clark.91@mail.service.com      emily_clark.91  mail.service.com
# 157                    john.smith@gmail          john.smith             gmail
# 167                 daniel_clark@icloud        daniel_clark            icloud
# 176  christopher89_bell@sub.company.com  christopher89_bell   sub.company.com
# 191      alice_3890.brown@company.co.uk    alice_3890.brown     company.co.uk
# 248         john.doe1990@sub.domain.com        john.doe1990    sub.domain.com
# 490              james.lewis@protonmail         james.lewis        protonmail
# 581               rebecca.scott@outlook       rebecca.scott           outlook
# 669        julia.doe4321@sub.domain.com       julia.doe4321    sub.domain.com
# 871      laura_1992.brown@company.co.uk    laura_1992.brown     company.co.uk
# 888     tom_clark.6543@mail.service.com      tom_clark.6543  mail.service.com
#
#      valid_email  valid_check
# 88         False        False
# 150        False        False
# 157        False        False
# 167        False        False
# 176        False        False
# 191        False        False
# 248        False        False
# 490        False        False
# 581        False        False
# 669        False        False
# 871        False        False
# 888        False        False

# %%
df[df['domain']=='.com']
# Out:
#                                email                   username domain  \
# 155            thomas.hall@gmail@com           thomas.hallgmail   .com
# 1037  matthew.roberts@protonmail@com  matthew.robertsprotonmail   .com
#
#       valid_email
# 155         False
# 1037        False

# %%
# manually correct the rest
df.loc[df['domain']=='yahoo', 'domain'] = 'yahoo.com'
df.loc[df['domain']=='gmail', 'domain'] = 'gmail.com'
df.loc[df['domain']=='icloud', 'domain'] = 'icloud.com'
df.loc[df['domain']=='outlook', 'domain'] = 'outlook.com'
df.loc[df['domain']=='protonmail', 'domain'] = 'protonmail.com'
df.loc[df['username']=='thomas.hallgmail', ['username','domain']] = ['thomas.hall', 'gmail.com']
df.loc[df['username']=='matthew.robertsprotonmail', ['username','domain']] = ['matthew.roberts', 'protonmail.com']
df['valid_check'] = df['domain'].apply(check_email_format)
df[df['valid_check'] == False]
# Out:
#                                   email            username            domain  \
# 150     emily_clark.91@mail.service.com      emily_clark.91  mail.service.com
# 176  christopher89_bell@sub.company.com  christopher89_bell   sub.company.com
# 191      alice_3890.brown@company.co.uk    alice_3890.brown     company.co.uk
# 248         john.doe1990@sub.domain.com        john.doe1990    sub.domain.com
# 669        julia.doe4321@sub.domain.com       julia.doe4321    sub.domain.com
# 871      laura_1992.brown@company.co.uk    laura_1992.brown     company.co.uk
# 888     tom_clark.6543@mail.service.com      tom_clark.6543  mail.service.com
#
#      valid_email  valid_check
# 150         True        False
# 176         True        False
# 191         True        False
# 248         True        False
# 669         True        False
# 871         True        False
# 888         True        False

# %%
# rest should be valid
df.loc[df['valid_check'] == False, 'valid_email'] = True
df.drop(columns=['valid_check'], inplace=True)

# %% [markdown]
# Step 3 Feature engineering and EDA

# %%
def find_potential_birth_year(user_name):
    # Corrected regex to capture both 4-digit and 2-digit years
    birth_year = re.findall(r'(19\d{2}|200\d|2010|\d{2})', user_name)
    if birth_year:
        year = int(birth_year[0])
        if year < 100:  # Handle two-digit years
            year += 1900 if year >= 20 else 2000
        return year
    return None

# %%
df['birth_year'] = df['username'].apply(find_potential_birth_year)
df
# Out:
#                                 email            username          domain  \
# 0           Elody_OConner51@gmail.com     Elody_OConner51       gmail.com
# 1               lily.long85@yahoo.com         lily.long85       yahoo.com
# 2            simon.ward@protonmailcom          simon.ward  protonmail.com
# 3       benjamin.phillips@hotmail.com   benjamin.phillips     hotmail.com
# 4               robert.walker@aol.com       robert.walker         aol.com
# ...                               ...                 ...             ...
# 1068         grace.hughes@hotmail.com        grace.hughes     hotmail.com
# 1069  grace92_anderson@protonmail.com    grace92_anderson  protonmail.com
# 1070        Marshall_Upton32@mail.com    Marshall_Upton32        mail.com
# 1071    caleb1996_phillips@icloud.com  caleb1996_phillips      icloud.com
# 1072     Floyd_Lueilwitz@tutanota.com     Floyd_Lueilwitz    tutanota.com
#
#       valid_email  birth_year
# 0            True      1951.0
# 1            True      1985.0
# 2           False         NaN
# 3            True         NaN
# 4            True         NaN
# ...           ...         ...
# 1068         True         NaN
# 1069         True      1992.0
# 1070         True      1932.0
# 1071         True      1996.0
# 1072         True         NaN
#
# [1073 rows x 5 columns]
